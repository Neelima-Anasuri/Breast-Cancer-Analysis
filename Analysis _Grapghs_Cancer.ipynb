# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\HARI\Desktop\Neelima\Reva\PaperPresentation\Cancer.csv")

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
import numpy as np                     # For mathematical calculations
import seaborn as sns                  # For data visualization
import matplotlib.pyplot as plt        # For plotting graphs
# %matplotlib inline
import warnings                        # To ignore any warnings
warnings.filterwarnings("ignore")

# %%
#Independent Variable (Numerical)
plt.figure(1)
plt.subplot(121)
sns.distplot(data['radius_mean']);

plt.subplot(122)
data['radius_mean'].plot.box(figsize=(16,5))

plt.show()

# %%
#Independent Variable (Numerical)
plt.figure(1)
plt.subplot(121)
sns.distplot(data['texture_mean']);

plt.subplot(122)
data['texture_mean'].plot.box(figsize=(16,5))

plt.show()

# %%
#Independent Variable (Numerical)
plt.figure(1)
plt.subplot(121)
sns.distplot(data['perimeter_mean']);

plt.subplot(122)
data['perimeter_mean'].plot.box(figsize=(16,5))

plt.show()

# %%
#Independent Variable (Numerical)
plt.figure(1)
plt.subplot(121)
sns.distplot(data['smoothness_mean']);

plt.subplot(122)
data['smoothness_mean'].plot.box(figsize=(16,5))

plt.show()

# %%
#Independent Variable (Numerical)
plt.figure(1)
plt.subplot(121)
sns.distplot(data['compactness_mean']);

plt.subplot(122)
data['compactness_mean'].plot.box(figsize=(16,5))

plt.show()

# %%
radius_mean_bin=pd.crosstab(round(data['radius_mean'],0),data['diagnosis'])
radius_mean_bin.div(radius_mean_bin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.xlabel('radius_mean')
P = plt.ylabel('Percentage')

# %%
texture_mean_bin=pd.crosstab(round(data['texture_mean'],0),data['diagnosis'])
texture_mean_bin.div(texture_mean_bin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.xlabel('texture_mean')
P = plt.ylabel('Percentage')
